# %% [markdown]
# #	What is HyDE?
#
# Hypothetical Document Embeddings (HyDE) is an advance RAG technique that generates synthetic document embeddings based on the query, rather than relying solely on existing document embeddings. This approach creates a "hypothetical" perfect document that would ideally answer the query, and then uses this embedding to retrieve the most similar actual documents from the database. HyDE aims to bridge the gap between query intent and document content, especially for complex or nuanced queries.
#
# # HyDE-RAG Implementation:
#
# 1. **Hypothetical Document Generation:** We use the LLM to generate a hypothetical passage that would answer the given query.
# 2. **Retrieval using Hypothetical Document:** We use the generated hypothetical document to retrieve relevant passages from our vector store.
# 3. **Final Response Generation:** Using the retrieved context, we generate a final response to the original query.

# %% [markdown]
# # Install required libraries

# %%
# !pip install -q -U \
     Sentence-transformers==3.0.1 \
     langchain==0.2.11 \
     langchain-google-genai==1.0.7 \
     langchain-chroma==0.1.2 \
     langchain-community==0.2.10 \
     einops==0.8.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 62.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.9/379.9 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.1/140.1 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 522.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 51.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 87.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 78.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 88.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.3 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %% [markdown]
# # Import related libraries related to Langchain, HuggingfaceEmbedding

# %%
from langchain_google_genai import (
    ChatGoogleGenerativeAI,
    HarmBlockThreshold,
    HarmCategory,
)
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema import Document
from langchain.document_loaders import WebBaseLoader
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
import os
import getpass

# %% [markdown]
# # Provide Google API Key. You can create Google API key at following link
#
# [Google Gemini-Pro API Creation Link](https://console.cloud.google.com/apis/credentials)
#
# [YouTube Video](https://www.youtube.com/watch?v=ZHX7zxvDfoc)

# %%
os.environ["GOOGLE_API_KEY"] = getpass.getpass()
# Out:
# ··········

# %% [markdown]
# # Provide Huggingface API Key. You can create Huggingface API key at following link
#
# [Higgingface API Creation Link](https://huggingface.co/settings/tokens)

# %%
os.environ["HF_TOKEN"] = getpass.getpass()
# Out:
# ··········

# %% [markdown]
# # Step 1: Load and preprocess data code

# %%
def load_and_process_data(url):
    # Load data from web
    loader = WebBaseLoader(url)
    data = loader.load()

    # Split text into chunks (Experiment with Chunk Size and Chunk Overlap to get optimal chunking)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    chunks = text_splitter.split_documents(data)

    return chunks

# %% [markdown]
# # Step 2: Create vector store code

# %%
def create_vector_store(chunks):
    embeddings = HuggingFaceEmbeddings(model_name="nomic-ai/nomic-embed-text-v1.5", model_kwargs = {'trust_remote_code': True})
    vectorstore = Chroma.from_documents(chunks, embeddings)
    return vectorstore

# %% [markdown]
# # Step 3: HyDE-RAG related code
#
# 1. **Hypothetical Document Generation:** We use the LLM to generate a hypothetical passage that would answer the given query.
# 2. **Retrieval using Hypothetical Document:** We use the generated hypothetical document to retrieve relevant passages from our vector store.
# 3. **Final Response Generation:** Using the retrieved context, we generate a final response to the original query.

# %%
def hyde_rag(query, vectorstore, llm):
    # Generate hypothetical document
    hyde_prompt = ChatPromptTemplate.from_template(
        "Given the following question, generate a hypothetical passage that would answer this question:\nQuestion: {query}\nHypothetical Passage:"
    )
    hyde_chain = hyde_prompt | llm
    hypothetical_doc = hyde_chain.invoke({"query": query})

    # Retrieve relevant documents using the hypothetical document
    retrieved_docs = vectorstore.similarity_search(hypothetical_doc.content, k=3)
    context = "\n".join([doc.page_content for doc in retrieved_docs])

    # Generate final response
    final_prompt = ChatPromptTemplate.from_template(
        "Based on the following context, please answer the question:\nContext: {context}\nQuestion: {query}\nAnswer:"
    )
    final_chain = final_prompt | llm
    final_response = final_chain.invoke({"context": context, "query": query})

    return {
        "hypothetical_document": hypothetical_doc.content,
        "retrieved_context": context,
        "final_answer": final_response.content
    }

# %% [markdown]
# # Step 4: Create chunk of web data to Chroma Vector Store

# %%
# Initialize the gemini-pro language model with specified settings (Change temeprature  and other parameters as per your requirement)
llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest", temperature=0.3, safety_settings={
          HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
        },)

# Load and process data
url = "https://en.wikipedia.org/wiki/Artificial_intelligence"
chunks = load_and_process_data(url)

# Create vector store
vectorstore = create_vector_store(chunks)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# modules.json:   0%|          | 0.00/255 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/140 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/71.2k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# configuration_hf_nomic_bert.py:   0%|          | 0.00/1.96k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - configuration_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_hf_nomic_bert.py:   0%|          | 0.00/84.7k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - modeling_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/547M [00:00<?, ?B/s]
# WARNING:transformers_modules.nomic-ai.nomic-bert-2048.e55a7d4324f65581af5f483e830b80f34680e8ff.modeling_hf_nomic_bert:<All keys matched successfully>
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %% [markdown]
# # Step 5: Run HyDE-RAG
#
# This implementation shows the key parts of HyDE-RAG:
#
# 1. Generation of a hypothetical document based on the query
# 2. Using the hypothetical document for retrieval instead of the original query
# 3. Final response generation using the retrieved context

# %%
# Example query
query = "What are the ethical considerations in AI development?"
result = hyde_rag(query, vectorstore, llm)

print("Hypothetical Document:")
print(result["hypothetical_document"])
print("\nRetrieved Context:")
print(result["retrieved_context"])
print("\nFinal Answer:")
print(result["final_answer"])
# Out:
# Hypothetical Document:
# ## The Ethical Minefield of Artificial Intelligence
#
# The rapid advancement of artificial intelligence (AI) presents humanity with a thrilling yet daunting future. While AI promises to revolutionize countless aspects of our lives, from healthcare to transportation, it also raises a complex web of ethical considerations that demand careful examination.
#
# One primary concern revolves around **bias and discrimination**. AI systems are trained on vast datasets, and if these datasets reflect existing societal biases, the resulting AI can perpetuate and even amplify these inequalities. Imagine an AI-powered hiring tool trained on data where men predominantly occupy leadership roles. This tool might unfairly favor male candidates, further entrenching existing gender disparities. Therefore, ensuring diverse and representative datasets, alongside rigorous testing for bias, is crucial for ethical AI development.
#
# Another critical consideration is **privacy and surveillance**. AI thrives on data, often requiring access to personal information to function effectively. This raises concerns about the potential for misuse, particularly in the context of facial recognition technology and predictive policing. Striking a balance between leveraging AI's potential and safeguarding individual privacy is paramount. Transparent data collection practices, clear consent mechanisms, and robust data security measures are essential to navigate this ethical tightrope.
#
# Furthermore, the issue of **accountability and transparency** looms large. As AI systems become increasingly complex and autonomous, determining responsibility for their actions becomes increasingly challenging. If an AI-powered medical device makes an incorrect diagnosis, who is accountable: the developers, the healthcare providers, or the AI itself? Establishing clear lines of responsibility and ensuring transparency in AI decision-making processes is crucial for building trust and ensuring ethical deployment.
#
# Finally, the potential for **job displacement** due to automation cannot be ignored. While AI can undoubtedly enhance productivity and efficiency, it also raises concerns about widespread unemployment and economic inequality.  Ethical AI development necessitates proactive measures to mitigate these risks, such as investing in education and retraining programs to equip individuals with the skills needed to thrive in an AI-driven economy.
#
# In conclusion, the ethical considerations surrounding AI development are multifaceted and demand careful consideration. By prioritizing fairness, transparency, accountability, and human well-being, we can harness the immense potential of AI while mitigating its potential pitfalls, paving the way for a future where technology empowers and benefits all of humanity.
#
#
# Retrieved Context:
# Ethical machines and alignment
# Main articles: Machine ethics, AI safety, Friendly artificial intelligence, Artificial moral agents, and Human Compatible
# Friendly AI are machines that have been designed from the beginning to minimize risks and to make choices that benefit humans. Eliezer Yudkowsky, who coined the term, argues that developing friendly AI should be a higher research priority: it may require a large investment and it must be completed before AI becomes an existential risk.[255]
# Machines with intelligence have the potential to use their intelligence to make ethical decisions. The field of machine ethics provides machines with ethical principles and procedures for resolving ethical dilemmas.[256]
# The field of machine ethics is also called computational morality,[256]
# and was founded at an AAAI symposium in 2005.[257]
# Promotion of the wellbeing of the people and communities that these technologies affect requires consideration of the social and ethical implications at all stages of AI system design, development and implementation, and collaboration between job roles such as data scientists, product managers, data engineers, domain experts, and delivery managers.[271]
#
# Final Answer:
# Ethical considerations in AI development are multifaceted and crucial to address throughout the entire lifecycle of AI systems. Here are some key points:
#
# * **Ensuring AI safety:** As AI becomes more powerful, it's crucial to ensure it doesn't pose a threat to humanity. This involves developing "Friendly AI" that prioritizes human well-being and aligning AI goals with human values.
# * **Embedding ethical principles:** Machine ethics aims to equip AI systems with the ability to make ethical decisions. This involves providing them with ethical principles, frameworks for resolving dilemmas, and promoting fairness and non-discrimination in their actions.
# * **Social impact and responsibility:** AI development should consider its impact on society, including potential job displacement, exacerbation of existing inequalities, and potential misuse. Developers and stakeholders must take responsibility for mitigating negative consequences.
# * **Transparency and explainability:**  Understanding how AI systems make decisions is crucial for building trust and ensuring accountability.  "Black box" AI systems raise concerns about bias, fairness, and the ability to address unintended consequences.
# * **Data privacy and security:** AI systems rely heavily on data, often sensitive personal information. Protecting this data from unauthorized access, use, and manipulation is paramount.
# * **Collaboration and inclusivity:** Addressing ethical challenges requires collaboration between various stakeholders, including data scientists, ethicists, policymakers, and the public.  Diverse perspectives are essential to ensure AI benefits all of humanity.
#
# In essence, ethical AI development goes beyond technical prowess. It demands a proactive and continuous effort to anticipate, address, and mitigate potential harms while ensuring AI technologies are used responsibly and for the benefit of humanity.
